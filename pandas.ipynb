# %%
import numpy as np
import pandas as pd
s = pd.Series([1, 3, 5, np.nan, 6, 8])


print(s)
print("**************************************************************")
dates = pd.date_range("20130101", periods=6)

print(dates)





print(s.dtypes)
print("**************************************************************")
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD")




print(df)
print("**************************************************************")


df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
print("**************************************************************")
print(df2)
print("********************Showing Datatypes used in the *****************")
print(df2.dtypes)
print("**************************************************************")
print(df.head)
print("**************************************************************")
print(df.tail)
print("******************Finding all index ************************")
print(df.index)
print("******************Showing all columns*************************")
print(df.columns)
print("**************************************************************")
print(df.to_numpy())
print("******************Describing the Dataframe**************************")
print(df.describe())
print("**************************************************************")
print(df.T)
print("****************Sorting**************************")
print(df.sort_index(axis=1, ascending=False))
print("**************************************************************")
print(df.sort_values(by="B"))

print("************Selecting particular row****************")

print(df["A"])
print("******************Slice*************************")
print(df[0:3])
print("***************Slice*****************************")
print(df["20130102":"20130104"])
print("**************************************************************")
# Out:
#   File "<ipython-input-1-6c7c4430c456>", line 18
#     df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD")
#                      ^
# SyntaxError: '(' was never closed
